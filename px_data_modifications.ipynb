# %%
import math

from scipy.signal import argrelextrema
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

df = pd.read_csv("data.csv")

# df["Wave Min"] = df["PxDataCol.LOW"][(df["PxDataCol.LOW"].shift(1) > df["PxDataCol.LOW"]) & (df["PxDataCol.LOW"].shift(-1) > df["PxDataCol.LOW"])]
# df["Wave Max"] = df["PxDataCol.HIGH"][(df["PxDataCol.HIGH"].shift(1) < df["PxDataCol.HIGH"]) & (df["PxDataCol.HIGH"].shift(-1) < df["PxDataCol.HIGH"])]



df
# Out:
#      Unnamed: 0  PxDataCol.OPEN  PxDataCol.HIGH  PxDataCol.LOW  \
# 0             0        14609.25        14611.75       14606.75
# 1             1        14610.75        14614.00       14610.50
# 2             2        14612.00        14612.25       14607.00
# 3             3        14608.75        14610.50       14606.00
# 4             4        14607.00        14607.00       14599.75
# ..          ...             ...             ...            ...
# 236         236        14586.75        14588.25       14586.25
# 237         237        14588.25        14590.00       14587.75
# 238         238        14589.25        14594.50       14586.75
# 239         239        14594.00        14595.50       14592.00
# 240         240        14594.25        14595.25       14593.75
#
#      PxDataCol.CLOSE  PxDataCol.EPOCH_SEC  PxDataCol.VOLUME  \
# 0           14610.00           1644276600               243
# 1           14612.25           1644276660               139
# ...

# %%
from pandas import DataFrame

double_high_dot = []

found_1 = False

for date, row in df.iterrows():
    if not math.isnan(row["Wave Max"]):
        if found_1:
            double_high_dot.append((row["PxDataCol.DATE"], row["Wave Max"]))
            found_1 = False
        else:
            found_1 = True

    if not math.isnan(row["Wave Min"]):
        found_1 = False

df2 = DataFrame(double_high_dot, columns=["date", "dot"])
df2
# Out:
#                         date       dot
# 0  2022-02-07 17:48:00-06:00  14616.00
# 1  2022-02-07 18:20:00-06:00  14615.75
# 2  2022-02-07 18:33:00-06:00  14602.00
# 3  2022-02-07 19:21:00-06:00  14598.00

# %%
fig = make_subplots(
    rows=1,
    vertical_spacing=0.02,
    shared_xaxes=True,
    specs=[
        [{}],
    ],
    row_heights=[7],
)
fig.add_trace(
    go.Candlestick(
        x=df['PxDataCol.DATE'],
        open=df['PxDataCol.OPEN'],
        high=df['PxDataCol.HIGH'],
        low=df['PxDataCol.LOW'],
        close=df['PxDataCol.CLOSE'],
    ),
    row=1,
    col=1,
)
fig.add_trace(
    go.Scatter(
        x=df["PxDataCol.DATE"],
        y=df["Wave Min"],
        mode="markers",
        marker=dict(
            color="yellow"
        ),
    ),
    row=1,
    col=1,
)
fig.add_trace(
    go.Scatter(
        x=df["PxDataCol.DATE"],
        y=df["Wave Max"],
        mode="markers",
        marker=dict(
            color="purple"
        ),
    ),
    row=1,
    col=1,
)
fig.add_trace(
    go.Scatter(
        x=df2["date"],
        y=df2["dot"],
        mode="markers",
        marker=dict(
            color="blue"
        ),
    ),
    row=1,
    col=1,
)
fig.update_layout(
    margin={"l": 20, "r": 20, "b": 20, "t": 20, "pad": 4},
    height=650,
    xaxis_rangeslider_visible=False,
)
fig.show()
# Out:
# <div>                            <div id="2b8c7a24-c452-42ea-9d99-2a0908e5c422" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b8c7a24-c452-42ea-9d99-2a0908e5c422")) {                    Plotly.newPlot(                        "2b8c7a24-c452-42ea-9d99-2a0908e5c422",                        [{"close":[14610.0,14612.25,14608.75,14607.25,14602.75,14604.0,14602.5,14605.0,14606.75,14604.75,14607.75,14606.0,14606.5,14606.0,14608.25,14608.25,14611.25,14611.75,14614.25,14612.25,14613.5,14609.75,14611.25,14608.75,14608.5,14606.0,14608.75,14608.75,14610.5,14610.75,14617.75,14614.0,14613.5,14617.25,14618.0,14615.0,14617.5,14615.75,14614.25,14612.25,14611.5,14607.5,14607.75,14607.0,14609.0,14614.0,14612.75,14610.25,14614.0,14614.75,14611.5,14610.75,14609.0,1459
# ...
